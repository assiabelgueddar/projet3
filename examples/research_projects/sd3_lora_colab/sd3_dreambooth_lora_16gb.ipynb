# %% [markdown]
# # Running Stable Diffusion 3 (SD3) DreamBooth LoRA training under 16GB GPU VRAM

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install -q -U git+https://github.com/huggingface/diffusers
# !pip install -q -U \
    transformers \
    accelerate \
    wandb \
    bitsandbytes \
    peft
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 115.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# As SD3 is gated, before using it with diffusers you first need to go to the [Stable Diffusion 3 Medium Hugging Face page](https://huggingface.co/stabilityai/stable-diffusion-3-medium-diffusers), fill in the form and accept the gate. Once you are in, you need to log in so that your system knows you’ve accepted the gate. Use the command below to log in:

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n)
# Token is valid (permission: fineGrained).
# The token `STD1` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `STD1`

# %% [markdown]
# ## Clone `diffusers`

# %%
# !git clone https://github.com/huggingface/diffusers
# %cd diffusers/examples/research_projects/sd3_lora_colab
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 93353, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 93353 (delta 22), reused 25 (delta 10), pack-reused 93307 (from 2)
# Receiving objects: 100% (93353/93353), 69.44 MiB | 15.90 MiB/s, done.
# Resolving deltas: 100% (68848/68848), done.
# /content/diffusers/examples/research_projects/sd3_lora_colab

# %% [markdown]
# ## Download instance data images

# %%
from huggingface_hub import snapshot_download

local_dir = "./dog"
snapshot_download(
    "diffusers/dog-example",
    local_dir=local_dir, repo_type="dataset",
    ignore_patterns=".gitattributes",
)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# '/content/diffusers/examples/research_projects/sd3_lora_colab/dog'

# %%
# !rm -rf dog/.cache

# %% [markdown]
# ## Compute embeddings
#
# Here we are using the default instance prompt "a photo of sks dog". But you can configure this. Refer to the `compute_embeddings.py` script for details on other supported arguments.

# %%
# !python compute_embeddings.py
# Out:
# 2025-05-26 11:00:10.522710: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748257210.542667    5538 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748257210.548808    5538 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-26 11:00:10.570628: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# config.json: 100% 740/740 [00:00<00:00, 4.55MB/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json: 100% 19.9k/19.9k [00:00<00:00, 70.4MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0% 0.00/4.99G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/4.53G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0% 10.5M/4.99G [00:00<00:59, 83.3MB/s]
#
# model-00002-of-00002.safetensors:   0% 10.5M/4.53G [00:00<00:44, 102MB/s]
# model-00001-of-00002.safetensors:   1% 31.5M/4.99G [00:00<00:43, 114MB/s]
#
# model-00002-of-00002.safetensors:   1% 31.5M/4.53G [00:00<00:37, 119MB/s]
# model-00001-of-00002.safetensors:   1% 52.4M/4.99G [00:00<00:34, 142MB/s]
#
# model-00002-of-00002.safetensors:   1% 52.4M/4.53G [00:00<00:32, 138MB/s]
#
# model-00002-of-00002.safetensors:   2% 73.4M/4.53G [00:00<00:33, 133MB/s]
# model-00001-of-00002.safetensors:   1% 73.4M/4.99G [00:00<00:40, 121MB/s]
#
# model-00002-of-00002.safetensors:   2% 94.4M/4.53G [00:00<00:30, 143MB/s]
# model-00001-of-00002.safetensors:   2% 94.4M/4.99G [00:00<00:37, 129MB/s]
#
# model-00002-of-00002.safetensors:   3% 115M/4.53G [00:00<00:28, 157MB/s]
# model-00001-of-00002.safetensors:   2% 115M/4.99G [00:00<00:33, 145MB/s]
#
# model-00002-of-00002.safetensors:   3% 136M/4.53G [00:00<00:26, 164MB/s]
# model-00001-of-00002.safetensors:   3% 147M/4.99G [00:01<00:28, 173MB/s]
#
# model-00002-of-00002.safetensors:   4% 168M/4.53G [00:01<00:24, 175MB/s]
# model-00001-of-00002.safetensors:   3% 168M/4.99G [00:01<00:31, 151MB/s]
#
# model-00002-of-00002.safetensors:   4% 189M/4.53G [00:01<00:31, 138MB/s]
# model-00001-of-00002.safetensors:   4% 189M/4.99G [00:01<00:38, 126MB/s]
#
# model-00002-of-00002.safetensors:   5% 210M/4.53G [00:01<00:37, 116MB/s]
# model-00001-of-00002.safetensors:   4% 210M/4.99G [00:01<00:43, 109MB/s]
#
# model-00002-of-00002.safetensors:   5% 231M/4.53G [00:01<00:38, 111MB/s]
# model-00001-of-00002.safetensors:   5% 231M/4.99G [00:01<00:46, 103MB/s]
#
# model-00002-of-00002.safetensors:   6% 252M/4.53G [00:02<01:02, 68.0MB/s]
# model-00001-of-00002.safetensors:   5% 252M/4.99G [00:07<06:55, 11.4MB/s]
#
# model-00002-of-00002.safetensors:   6% 262M/4.53G [00:07<07:00, 10.2MB/s]
#
# model-00002-of-00002.safetensors:   6% 294M/4.53G [00:07<04:05, 17.3MB/s]
# model-00001-of-00002.safetensors:   6% 283M/4.99G [00:07<04:20, 18.1MB/s]
#
# model-00002-of-00002.safetensors:   7% 315M/4.53G [00:07<02:59, 23.5MB/s]
# model-00001-of-00002.safetensors:   6% 304M/4.99G [00:07<03:15, 24.0MB/s]
#
# model-00002-of-00002.safetensors:   7% 336M/4.53G [00:07<02:15, 31.0MB/s]
# model-00001-of-00002.safetensors:   7% 325M/4.99G [00:07<02:29, 31.2MB/s]
#
# model-00002-of-00002.safetensors:   8% 357M/4.53G [00:08<01:41, 41.0MB/s]
# model-00001-of-00002.safetensors:   7% 346M/4.99G [00:08<01:54, 40.7MB/s]
#
# model-00002-of-00002.safetensors:   9% 388M/4.53G [00:08<01:09, 60.0MB/s]
# model-00001-of-00002.safetensors:   7% 367M/4.99G [00:08<01:28, 52.2MB/s]
#
# model-00002-of-00002.safetensors:   9% 409M/4.53G [00:08<01:00, 68.0MB/s]
# model-00001-of-00002.safetensors:   8% 388M/4.99G [00:08<01:16, 60.2MB/s]
# model-00001-of-00002.safetensors:   8% 409M/4.99G [00:08<01:04, 71.2MB/s]
#
# model-00002-of-00002.safetensors:   9% 430M/4.53G [00:08<00:54, 74.8MB/s]
# model-00001-of-00002.safetensors:   9% 430M/4.99G [00:08<00:55, 82.4MB/s]
#
# model-00002-of-00002.safetensors:  10% 451M/4.53G [00:08<00:48, 84.1MB/s]
# model-00001-of-00002.safetensors:   9% 451M/4.99G [00:09<01:01, 73.3MB/s]
#
# model-00002-of-00002.safetensors:  10% 472M/4.53G [00:09<00:56, 71.8MB/s]
# model-00001-of-00002.safetensors:   9% 472M/4.99G [00:15<07:50, 9.62MB/s]
#
# model-00002-of-00002.safetensors:  11% 493M/4.53G [00:15<06:51, 9.81MB/s]
# model-00001-of-00002.safetensors:  10% 503M/4.99G [00:15<04:51, 15.4MB/s]
#
# model-00002-of-00002.safetensors:  12% 524M/4.53G [00:15<04:17, 15.6MB/s]
# model-00001-of-00002.safetensors:  10% 524M/4.99G [00:16<03:38, 20.5MB/s]
#
# model-00002-of-00002.safetensors:  12% 545M/4.53G [00:16<03:12, 20.7MB/s]
# model-00001-of-00002.safetensors:  11% 545M/4.99G [00:16<02:44, 27.0MB/s]
#
# model-00002-of-00002.safetensors:  12% 566M/4.53G [00:16<02:26, 27.1MB/s]
# model-00001-of-00002.safetensors:  11% 566M/4.99G [00:16<02:04, 35.5MB/s]
#
# model-00002-of-00002.safetensors:  13% 587M/4.53G [00:16<01:50, 35.6MB/s]
#
# model-00002-of-00002.safetensors:  13% 608M/4.53G [00:16<01:23, 46.7MB/s]
# model-00001-of-00002.safetensors:  12% 598M/4.99G [00:16<01:25, 51.3MB/s]
#
# model-00002-of-00002.safetensors:  14% 629M/4.53G [00:16<01:10, 55.4MB/s]
# model-00001-of-00002.safetensors:  12% 619M/4.99G [00:16<01:13, 59.3MB/s]
#
# model-00002-of-00002.safetensors:  14% 650M/4.53G [00:16<00:57, 67.4MB/s]
# model-00001-of-00002.safetensors:  13% 640M/4.99G [00:16<01:06, 65.4MB/s]
#
# model-00002-of-00002.safetensors:  15% 671M/4.53G [00:16<00:49, 77.2MB/s]
# model-00001-of-00002.safetensors:  13% 661M/4.99G [00:16<00:54, 79.3MB/s]
# model-00001-of-00002.safetensors:  14% 682M/4.99G [00:17<00:47, 91.7MB/s]
#
# model-00002-of-00002.safetensors:  15% 692M/4.53G [00:17<00:45, 83.6MB/s]
# model-00001-of-00002.safetensors:  14% 703M/4.99G [00:17<00:53, 80.6MB/s]
#
# model-00002-of-00002.safetensors:  16% 713M/4.53G [00:17<00:52, 72.6MB/s]
# model-00001-of-00002.safetensors:  14% 724M/4.99G [00:19<02:33, 27.8MB/s]
#
# model-00002-of-00002.safetensors:  16% 734M/4.53G [00:20<03:30, 18.0MB/s]
# model-00001-of-00002.safetensors:  15% 734M/4.99G [00:36<22:40, 3.13MB/s]
#
# model-00002-of-00002.safetensors:  16% 734M/4.53G [00:38<03:30, 18.0MB/s]
#
# model-00002-of-00002.safetensors:  16% 744M/4.53G [00:42<25:53, 2.44MB/s]
# model-00001-of-00002.safetensors:  15% 734M/4.99G [00:48<22:40, 3.13MB/s]
#
# model-00002-of-00002.safetensors:  16% 744M/4.53G [00:58<25:53, 2.44MB/s]
#
# model-00002-of-00002.safetensors:  17% 755M/4.53G [01:02<44:18, 1.42MB/s]
# model-00001-of-00002.safetensors:  15% 744M/4.99G [01:02<52:02, 1.36MB/s]
#
# model-00002-of-00002.safetensors:  17% 765M/4.53G [01:02<34:36, 1.81MB/s]
# model-00001-of-00002.safetensors:  15% 755M/4.99G [01:02<40:44, 1.73MB/s]
#
# model-00002-of-00002.safetensors:  17% 776M/4.53G [01:02<26:38, 2.35MB/s]
# model-00001-of-00002.safetensors:  15% 765M/4.99G [01:02<31:21, 2.25MB/s]
#
# model-00002-of-00002.safetensors:  17% 786M/4.53G [01:02<19:57, 3.13MB/s]
# model-00001-of-00002.safetensors:  16% 776M/4.99G [01:02<23:32, 2.99MB/s]
#
# model-00002-of-00002.safetensors:  18% 797M/4.53G [01:02<14:45, 4.22MB/s]
# model-00001-of-00002.safetensors:  16% 797M/4.99G [01:02<13:44, 5.09MB/s]
#
# model-00002-of-00002.safetensors:  18% 828M/4.53G [01:03<06:57, 8.86MB/s]
# model-00001-of-00002.safetensors:  16% 818M/4.99G [01:03<08:40, 8.02MB/s]
#
# model-00002-of-00002.safetensors:  19% 849M/4.53G [01:03<04:41, 13.1MB/s]
# model-00001-of-00002.safetensors:  17% 839M/4.99G [01:03<05:47, 12.0MB/s]
#
# model-00002-of-00002.safetensors:  19% 870M/4.53G [01:03<03:15, 18.7MB/s]
# model-00001-of-00002.safetensors:  17% 860M/4.99G [01:03<03:58, 17.3MB/s]
#
# model-00002-of-00002.safetensors:  20% 891M/4.53G [01:03<02:20, 25.9MB/s]
# model-00001-of-00002.safetensors:  18% 881M/4.99G [01:03<02:52, 23.8MB/s]
#
# model-00002-of-00002.safetensors:  20% 912M/4.53G [01:03<01:45, 34.3MB/s]
#
# model-00002-of-00002.safetensors:  21% 933M/4.53G [01:03<01:18, 45.9MB/s]
# model-00001-of-00002.safetensors:  18% 902M/4.99G [01:03<02:11, 31.2MB/s]
#
# model-00002-of-00002.safetensors:  21% 954M/4.53G [01:03<01:03, 56.7MB/s]
# model-00001-of-00002.safetensors:  18% 923M/4.99G [01:03<01:38, 41.3MB/s]
#
# model-00002-of-00002.safetensors:  22% 975M/4.53G [01:04<00:51, 69.0MB/s]
# model-00001-of-00002.safetensors:  19% 944M/4.99G [01:04<01:16, 52.8MB/s]
# model-00001-of-00002.safetensors:  19% 965M/4.99G [01:04<01:02, 64.8MB/s]
#
# model-00002-of-00002.safetensors:  22% 996M/4.53G [01:04<00:45, 76.9MB/s]
# model-00001-of-00002.safetensors:  20% 986M/4.99G [01:04<00:53, 75.4MB/s]
#
# model-00002-of-00002.safetensors:  22% 1.02G/4.53G [01:04<00:41, 83.9MB/s]
#
# model-00002-of-00002.safetensors:  23% 1.04G/4.53G [01:04<00:36, 94.6MB/s]
# model-00001-of-00002.safetensors:  20% 1.01G/4.99G [01:04<00:48, 81.6MB/s]
#
# model-00002-of-00002.safetensors:  23% 1.06G/4.53G [01:04<00:31, 111MB/s]
# model-00001-of-00002.safetensors:  21% 1.03G/4.99G [01:04<00:41, 95.4MB/s]
# model-00001-of-00002.safetensors:  21% 1.05G/4.99G [01:04<00:38, 101MB/s]
#
# model-00002-of-00002.safetensors:  24% 1.08G/4.53G [01:04<00:34, 101MB/s]
# model-00001-of-00002.safetensors:  21% 1.07G/4.99G [01:05<00:34, 114MB/s]
#
# model-00002-of-00002.safetensors:  24% 1.10G/4.53G [01:05<00:33, 102MB/s]
# model-00001-of-00002.safetensors:  22% 1.09G/4.99G [01:05<00:36, 107MB/s]
#
# model-00002-of-00002.safetensors:  25% 1.12G/4.53G [01:05<00:32, 106MB/s]
# model-00001-of-00002.safetensors:  22% 1.11G/4.99G [01:05<00:32, 119MB/s]
#
# model-00002-of-00002.safetensors:  25% 1.14G/4.53G [01:05<00:27, 124MB/s]
# model-00001-of-00002.safetensors:  23% 1.13G/4.99G [01:05<00:32, 121MB/s]
#
# model-00002-of-00002.safetensors:  26% 1.16G/4.53G [01:05<00:25, 131MB/s]
# model-00001-of-00002.safetensors:  23% 1.15G/4.99G [01:05<00:32, 118MB/s]
#
# model-00002-of-00002.safetensors:  26% 1.18G/4.53G [01:05<00:26, 126MB/s]
# model-00001-of-00002.safetensors:  24% 1.17G/4.99G [01:05<00:33, 114MB/s]
#
# model-00002-of-00002.safetensors:  27% 1.21G/4.53G [01:05<00:28, 118MB/s]
# model-00001-of-00002.safetensors:  24% 1.20G/4.99G [01:06<00:29, 127MB/s]
#
# model-00002-of-00002.safetensors:  27% 1.24G/4.53G [01:06<00:22, 144MB/s]
# model-00001-of-00002.safetensors:  24% 1.22G/4.99G [01:06<00:27, 139MB/s]
#
# model-00002-of-00002.safetensors:  28% 1.26G/4.53G [01:06<00:26, 124MB/s]
# model-00001-of-00002.safetensors:  25% 1.24G/4.99G [01:06<00:37, 99.2MB/s]
#
# model-00002-of-00002.safetensors:  28% 1.28G/4.53G [01:06<00:28, 113MB/s]
# model-00001-of-00002.safetensors:  25% 1.26G/4.99G [01:06<00:32, 115MB/s]
#
# model-00002-of-00002.safetensors:  29% 1.30G/4.53G [01:06<00:24, 130MB/s]
# model-00001-of-00002.safetensors:  26% 1.28G/4.99G [01:06<00:28, 131MB/s]
#
# model-00002-of-00002.safetensors:  29% 1.33G/4.53G [01:06<00:19, 161MB/s]
# model-00001-of-00002.safetensors:  26% 1.30G/4.99G [01:06<00:29, 124MB/s]
#
# model-00002-of-00002.safetensors:  30% 1.35G/4.53G [01:07<00:24, 129MB/s]
# model-00001-of-00002.safetensors:  26% 1.32G/4.99G [01:07<00:34, 106MB/s]
#
# model-00002-of-00002.safetensors:  30% 1.37G/4.53G [01:07<00:28, 111MB/s]
# model-00001-of-00002.safetensors:  27% 1.34G/4.99G [01:07<00:32, 113MB/s]
#
# model-00002-of-00002.safetensors:  31% 1.41G/4.53G [01:07<00:22, 139MB/s]
# model-00001-of-00002.safetensors:  27% 1.36G/4.99G [01:07<00:29, 122MB/s]
#
# model-00002-of-00002.safetensors:  31% 1.43G/4.53G [01:07<00:20, 152MB/s]
# model-00001-of-00002.safetensors:  28% 1.38G/4.99G [01:07<00:26, 138MB/s]
#
# model-00002-of-00002.safetensors:  32% 1.46G/4.53G [01:07<00:19, 159MB/s]
# model-00001-of-00002.safetensors:  28% 1.41G/4.99G [01:07<00:27, 129MB/s]
#
# model-00002-of-00002.safetensors:  33% 1.48G/4.53G [01:07<00:24, 124MB/s]
# model-00001-of-00002.safetensors:  29% 1.43G/4.99G [01:08<00:33, 106MB/s]
#
# model-00002-of-00002.safetensors:  33% 1.50G/4.53G [01:08<00:25, 121MB/s]
# model-00001-of-00002.safetensors:  29% 1.46G/4.99G [01:08<00:26, 136MB/s]
#
# model-00002-of-00002.safetensors:  34% 1.53G/4.53G [01:08<00:22, 133MB/s]
# model-00001-of-00002.safetensors:  30% 1.48G/4.99G [01:08<00:25, 136MB/s]
#
# model-00002-of-00002.safetensors:  34% 1.55G/4.53G [01:08<00:24, 120MB/s]
# model-00001-of-00002.safetensors:  30% 1.50G/4.99G [01:08<00:29, 120MB/s]
# model-00001-of-00002.safetensors:  30% 1.52G/4.99G [01:08<00:32, 108MB/s]
#
# model-00002-of-00002.safetensors:  35% 1.57G/4.53G [01:08<00:27, 106MB/s]
# model-00001-of-00002.safetensors:  31% 1.54G/4.99G [01:08<00:29, 118MB/s]
#
# model-00002-of-00002.safetensors:  35% 1.59G/4.53G [01:09<00:26, 112MB/s]
# model-00001-of-00002.safetensors:  31% 1.57G/4.99G [01:09<00:23, 143MB/s]
#
# model-00002-of-00002.safetensors:  36% 1.61G/4.53G [01:09<00:24, 121MB/s]
# model-00001-of-00002.safetensors:  32% 1.60G/4.99G [01:09<00:20, 164MB/s]
#
# model-00002-of-00002.safetensors:  36% 1.65G/4.53G [01:09<00:19, 145MB/s]
# model-00001-of-00002.safetensors:  33% 1.63G/4.99G [01:09<00:24, 135MB/s]
#
# model-00002-of-00002.safetensors:  37% 1.67G/4.53G [01:09<00:22, 125MB/s]
# model-00001-of-00002.safetensors:  33% 1.65G/4.99G [01:09<00:25, 132MB/s]
#
# model-00002-of-00002.safetensors:  37% 1.69G/4.53G [01:09<00:22, 126MB/s]
# model-00001-of-00002.safetensors:  33% 1.67G/4.99G [01:09<00:26, 126MB/s]
#
# model-00002-of-00002.safetensors:  38% 1.71G/4.53G [01:09<00:23, 118MB/s]
# model-00001-of-00002.safetensors:  34% 1.69G/4.99G [01:10<00:32, 101MB/s]
#
# model-00002-of-00002.safetensors:  38% 1.73G/4.53G [01:19<06:28, 7.20MB/s]
# model-00001-of-00002.safetensors:  34% 1.70G/4.99G [01:28<00:32, 101MB/s]
#
# model-00002-of-00002.safetensors:  38% 1.74G/4.53G [01:32<14:48, 3.14MB/s]
#
# model-00002-of-00002.safetensors:  38% 1.74G/4.53G [01:48<14:48, 3.14MB/s]
# model-00001-of-00002.safetensors:  34% 1.71G/4.99G [01:54<33:51, 1.62MB/s]
# model-00001-of-00002.safetensors:  34% 1.72G/4.99G [02:01<33:49, 1.61MB/s]
#
# model-00002-of-00002.safetensors:  39% 1.75G/4.53G [02:01<37:11, 1.25MB/s]
# model-00001-of-00002.safetensors:  35% 1.73G/4.99G [02:01<27:22, 1.99MB/s]
#
# model-00002-of-00002.safetensors:  39% 1.77G/4.53G [02:01<23:52, 1.93MB/s]
# model-00001-of-00002.safetensors:  35% 1.74G/4.99G [02:01<21:34, 2.51MB/s]
#
# model-00002-of-00002.safetensors:  39% 1.78G/4.53G [02:01<19:07, 2.40MB/s]
# model-00001-of-00002.safetensors:  35% 1.75G/4.99G [02:02<16:37, 3.25MB/s]
#
# model-00002-of-00002.safetensors:  40% 1.79G/4.53G [02:02<14:56, 3.05MB/s]
# model-00001-of-00002.safetensors:  35% 1.76G/4.99G [02:02<12:30, 4.31MB/s]
#
# model-00002-of-00002.safetensors:  40% 1.80G/4.53G [02:02<11:22, 4.00MB/s]
# model-00001-of-00002.safetensors:  35% 1.77G/4.99G [02:02<09:17, 5.78MB/s]
#
# model-00002-of-00002.safetensors:  40% 1.81G/4.53G [02:02<08:32, 5.30MB/s]
# model-00001-of-00002.safetensors:  36% 1.79G/4.99G [02:02<05:22, 9.93MB/s]
#
# model-00002-of-00002.safetensors:  41% 1.84G/4.53G [02:02<04:58, 9.03MB/s]
# model-00001-of-00002.safetensors:  36% 1.81G/4.99G [02:02<03:24, 15.5MB/s]
#
# model-00002-of-00002.safetensors:  41% 1.86G/4.53G [02:02<03:10, 14.0MB/s]
# model-00001-of-00002.safetensors:  37% 1.84G/4.99G [02:02<02:19, 22.7MB/s]
#
# model-00002-of-00002.safetensors:  41% 1.88G/4.53G [02:02<02:08, 20.7MB/s]
# model-00001-of-00002.safetensors:  37% 1.86G/4.99G [02:02<01:40, 31.2MB/s]
#
# model-00002-of-00002.safetensors:  42% 1.90G/4.53G [02:02<01:32, 28.5MB/s]
# model-00001-of-00002.safetensors:  38% 1.88G/4.99G [02:02<01:14, 41.7MB/s]
#
# model-00002-of-00002.safetensors:  42% 1.92G/4.53G [02:03<01:07, 38.5MB/s]
# model-00001-of-00002.safetensors:  38% 1.90G/4.99G [02:03<00:59, 52.2MB/s]
#
# model-00002-of-00002.safetensors:  43% 1.94G/4.53G [02:03<00:53, 48.5MB/s]
# model-00001-of-00002.safetensors:  38% 1.92G/4.99G [02:03<00:48, 63.3MB/s]
#
# model-00002-of-00002.safetensors:  43% 1.96G/4.53G [02:03<00:45, 56.2MB/s]
# model-00001-of-00002.safetensors:  39% 1.94G/4.99G [02:03<00:40, 75.1MB/s]
#
# model-00002-of-00002.safetensors:  44% 1.98G/4.53G [02:03<00:35, 71.6MB/s]
# model-00001-of-00002.safetensors:  39% 1.96G/4.99G [02:03<00:34, 86.8MB/s]
#
# model-00002-of-00002.safetensors:  44% 2.00G/4.53G [02:03<00:30, 81.8MB/s]
# model-00001-of-00002.safetensors:  40% 1.98G/4.99G [02:03<00:29, 103MB/s]
#
# model-00002-of-00002.safetensors:  45% 2.02G/4.53G [02:03<00:28, 87.8MB/s]
# model-00001-of-00002.safetensors:  40% 2.00G/4.99G [02:03<00:27, 108MB/s]
# model-00001-of-00002.safetensors:  41% 2.02G/4.99G [02:04<00:24, 123MB/s]
#
# model-00002-of-00002.safetensors:  45% 2.04G/4.53G [02:04<00:26, 95.0MB/s]
#
# model-00002-of-00002.safetensors:  46% 2.07G/4.53G [02:04<00:24, 98.7MB/s]
# model-00001-of-00002.safetensors:  41% 2.04G/4.99G [02:04<00:27, 109MB/s]
#
# model-00002-of-00002.safetensors:  46% 2.09G/4.53G [02:04<00:21, 115MB/s]
# model-00001-of-00002.safetensors:  42% 2.08G/4.99G [02:04<00:24, 119MB/s]
#
# model-00002-of-00002.safetensors:  47% 2.11G/4.53G [02:04<00:21, 111MB/s]
# model-00001-of-00002.safetensors:  42% 2.10G/4.99G [02:04<00:21, 134MB/s]
#
# model-00002-of-00002.safetensors:  47% 2.13G/4.53G [02:04<00:20, 115MB/s]
# model-00001-of-00002.safetensors:  42% 2.12G/4.99G [02:04<00:24, 115MB/s]
#
# model-00002-of-00002.safetensors:  47% 2.15G/4.53G [02:06<01:02, 38.1MB/s]
#
# model-00002-of-00002.safetensors:  48% 2.17G/4.53G [02:06<00:47, 49.2MB/s]
# model-00001-of-00002.safetensors:  43% 2.14G/4.99G [02:06<01:14, 38.2MB/s]
# model-00001-of-00002.safetensors:  43% 2.15G/4.99G [02:07<02:01, 23.3MB/s]
#
# model-00002-of-00002.safetensors:  48% 2.19G/4.53G [02:07<01:18, 29.7MB/s]
#
# model-00002-of-00002.safetensors:  49% 2.21G/4.53G [02:07<00:58, 39.9MB/s]
# model-00001-of-00002.safetensors:  43% 2.17G/4.99G [02:07<01:28, 31.9MB/s]
#
# model-00002-of-00002.safetensors:  50% 2.24G/4.53G [02:07<00:38, 59.8MB/s]
# model-00001-of-00002.safetensors:  44% 2.19G/4.99G [02:07<01:04, 43.5MB/s]
# model-00001-of-00002.safetensors:  44% 2.21G/4.99G [02:08<00:49, 56.1MB/s]
#
# model-00002-of-00002.safetensors:  50% 2.26G/4.53G [02:08<00:32, 68.9MB/s]
# model-00001-of-00002.safetensors:  45% 2.23G/4.99G [02:08<00:39, 70.6MB/s]
#
# model-00002-of-00002.safetensors:  50% 2.29G/4.53G [02:08<00:26, 84.0MB/s]
#
# model-00002-of-00002.safetensors:  51% 2.31G/4.53G [02:08<00:21, 101MB/s]
# model-00001-of-00002.safetensors:  45% 2.25G/4.99G [02:08<00:32, 85.1MB/s]
#
# model-00002-of-00002.safetensors:  51% 2.33G/4.53G [02:08<00:19, 116MB/s]
# model-00001-of-00002.safetensors:  46% 2.28G/4.99G [02:08<00:28, 94.9MB/s]
#
# model-00002-of-00002.safetensors:  52% 2.35G/4.53G [02:08<00:16, 130MB/s]
# model-00001-of-00002.safetensors:  46% 2.30G/4.99G [02:08<00:24, 111MB/s]
#
# model-00002-of-00002.safetensors:  52% 2.37G/4.53G [02:08<00:15, 143MB/s]
# model-00001-of-00002.safetensors:  46% 2.32G/4.99G [02:08<00:21, 127MB/s]
#
# model-00002-of-00002.safetensors:  53% 2.40G/4.53G [02:08<00:12, 168MB/s]
# model-00001-of-00002.safetensors:  47% 2.35G/4.99G [02:08<00:20, 131MB/s]
#
# model-00002-of-00002.safetensors:  53% 2.42G/4.53G [02:08<00:15, 137MB/s]
# model-00001-of-00002.safetensors:  47% 2.37G/4.99G [02:09<00:23, 113MB/s]
#
# model-00002-of-00002.safetensors:  54% 2.44G/4.53G [02:09<00:17, 123MB/s]
# model-00001-of-00002.safetensors:  48% 2.39G/4.99G [02:09<00:23, 110MB/s]
#
# model-00002-of-00002.safetensors:  54% 2.46G/4.53G [02:09<00:19, 105MB/s]
# model-00001-of-00002.safetensors:  48% 2.41G/4.99G [02:12<02:15, 19.1MB/s]
#
# model-00002-of-00002.safetensors:  55% 2.49G/4.53G [02:20<05:18, 6.41MB/s]
# model-00001-of-00002.safetensors:  48% 2.41G/4.99G [02:28<02:15, 19.1MB/s]
# model-00001-of-00002.safetensors:  48% 2.42G/4.99G [02:29<13:48, 3.11MB/s]
#
# model-00002-of-00002.safetensors:  55% 2.49G/4.53G [02:38<05:18, 6.41MB/s]
# model-00001-of-00002.safetensors:  48% 2.42G/4.99G [02:48<13:48, 3.11MB/s]
#
# model-00002-of-00002.safetensors:  55% 2.50G/4.53G [02:53<22:28, 1.51MB/s]
# model-00001-of-00002.safetensors:  49% 2.43G/4.99G [02:53<29:26, 1.45MB/s]
#
# model-00002-of-00002.safetensors:  56% 2.52G/4.53G [02:53<15:04, 2.23MB/s]
# model-00001-of-00002.safetensors:  49% 2.45G/4.99G [02:53<18:56, 2.23MB/s]
# model-00001-of-00002.safetensors:  49% 2.46G/4.99G [02:53<15:08, 2.79MB/s]
#
# model-00002-of-00002.safetensors:  56% 2.54G/4.53G [02:53<10:19, 3.22MB/s]
# model-00001-of-00002.safetensors:  50% 2.50G/4.99G [02:53<08:03, 5.17MB/s]
#
# model-00002-of-00002.safetensors:  57% 2.57G/4.53G [02:53<06:05, 5.37MB/s]
# model-00001-of-00002.safetensors:  51% 2.53G/4.99G [02:53<04:51, 8.46MB/s]
#
# model-00002-of-00002.safetensors:  57% 2.59G/4.53G [02:53<04:24, 7.35MB/s]
# model-00001-of-00002.safetensors:  51% 2.55G/4.99G [02:54<03:42, 11.0MB/s]
#
# model-00002-of-00002.safetensors:  58% 2.61G/4.53G [02:54<03:35, 8.92MB/s]
# model-00001-of-00002.safetensors:  51% 2.57G/4.99G [02:59<05:23, 7.50MB/s]
# model-00001-of-00002.safetensors:  52% 2.58G/4.99G [02:59<04:43, 8.51MB/s]
#
# model-00002-of-00002.safetensors:  58% 2.63G/4.53G [02:59<04:34, 6.92MB/s]
# model-00001-of-00002.safetensors:  52% 2.61G/4.99G [02:59<02:47, 14.3MB/s]
#
# model-00002-of-00002.safetensors:  59% 2.66G/4.53G [02:59<02:49, 11.0MB/s]
#
# model-00002-of-00002.safetensors:  59% 2.68G/4.53G [02:59<02:04, 14.8MB/s]
# model-00001-of-00002.safetensors:  53% 2.63G/4.99G [02:59<02:02, 19.3MB/s]
#
# model-00002-of-00002.safetensors:  60% 2.71G/4.53G [03:00<01:33, 19.5MB/s]
# model-00001-of-00002.safetensors:  53% 2.65G/4.99G [03:00<01:31, 25.6MB/s]
#
# model-00002-of-00002.safetensors:  60% 2.73G/4.53G [03:00<01:09, 25.8MB/s]
# model-00001-of-00002.safetensors:  54% 2.67G/4.99G [03:00<01:09, 33.4MB/s]
#
# model-00002-of-00002.safetensors:  61% 2.75G/4.53G [03:00<00:53, 33.6MB/s]
# model-00001-of-00002.safetensors:  54% 2.69G/4.99G [03:00<00:53, 42.7MB/s]
#
# model-00002-of-00002.safetensors:  61% 2.77G/4.53G [03:00<00:39, 44.2MB/s]
# model-00001-of-00002.safetensors:  54% 2.72G/4.99G [03:00<00:41, 55.1MB/s]
#
# model-00002-of-00002.safetensors:  62% 2.79G/4.53G [03:00<00:31, 55.4MB/s]
# model-00001-of-00002.safetensors:  55% 2.74G/4.99G [03:00<00:33, 68.0MB/s]
#
# model-00002-of-00002.safetensors:  62% 2.81G/4.53G [03:00<00:26, 65.1MB/s]
# model-00001-of-00002.safetensors:  55% 2.76G/4.99G [03:00<00:29, 76.5MB/s]
#
# model-00002-of-00002.safetensors:  62% 2.83G/4.53G [03:00<00:22, 76.1MB/s]
# model-00001-of-00002.safetensors:  56% 2.78G/4.99G [03:01<00:25, 85.4MB/s]
#
# model-00002-of-00002.safetensors:  63% 2.85G/4.53G [03:01<00:19, 85.0MB/s]
# model-00001-of-00002.safetensors:  56% 2.80G/4.99G [03:01<00:23, 94.7MB/s]
#
# model-00002-of-00002.safetensors:  63% 2.87G/4.53G [03:01<00:17, 96.0MB/s]
# model-00001-of-00002.safetensors:  56% 2.82G/4.99G [03:01<00:20, 104MB/s]
#
# model-00002-of-00002.safetensors:  64% 2.89G/4.53G [03:01<00:15, 104MB/s]
# model-00001-of-00002.safetensors:  57% 2.84G/4.99G [03:01<00:18, 114MB/s]
#
# model-00002-of-00002.safetensors:  64% 2.92G/4.53G [03:01<00:15, 102MB/s]
# model-00001-of-00002.safetensors:  57% 2.86G/4.99G [03:01<00:20, 106MB/s]
#
# model-00002-of-00002.safetensors:  65% 2.94G/4.53G [03:01<00:13, 120MB/s]
# model-00001-of-00002.safetensors:  58% 2.88G/4.99G [03:01<00:18, 112MB/s]
#
# model-00002-of-00002.safetensors:  65% 2.96G/4.53G [03:01<00:12, 129MB/s]
# model-00001-of-00002.safetensors:  58% 2.90G/4.99G [03:02<00:17, 120MB/s]
#
# model-00002-of-00002.safetensors:  66% 2.98G/4.53G [03:02<00:13, 117MB/s]
# model-00001-of-00002.safetensors:  59% 2.93G/4.99G [03:02<00:17, 117MB/s]
#
# model-00002-of-00002.safetensors:  66% 3.00G/4.53G [03:02<00:12, 125MB/s]
# model-00001-of-00002.safetensors:  59% 2.95G/4.99G [03:02<00:16, 122MB/s]
#
# model-00002-of-00002.safetensors:  67% 3.02G/4.53G [03:02<00:11, 136MB/s]
# model-00001-of-00002.safetensors:  59% 2.97G/4.99G [03:02<00:16, 126MB/s]
#
# model-00002-of-00002.safetensors:  67% 3.04G/4.53G [03:02<00:10, 140MB/s]
# model-00001-of-00002.safetensors:  60% 2.99G/4.99G [03:02<00:16, 124MB/s]
#
# model-00002-of-00002.safetensors:  68% 3.06G/4.53G [03:02<00:11, 129MB/s]
#
# model-00002-of-00002.safetensors:  68% 3.08G/4.53G [03:02<00:11, 128MB/s]
# model-00001-of-00002.safetensors:  60% 3.01G/4.99G [03:02<00:17, 116MB/s]
# model-00001-of-00002.safetensors:  61% 3.03G/4.99G [03:03<00:16, 116MB/s]
#
# model-00002-of-00002.safetensors:  69% 3.10G/4.53G [03:03<00:12, 118MB/s]
#
# model-00002-of-00002.safetensors:  69% 3.12G/4.53G [03:03<00:11, 125MB/s]
# model-00001-of-00002.safetensors:  61% 3.05G/4.99G [03:03<00:20, 96.3MB/s]
# model-00001-of-00002.safetensors:  62% 3.07G/4.99G [03:03<00:17, 112MB/s]
#
# model-00002-of-00002.safetensors:  69% 3.15G/4.53G [03:03<00:14, 98.8MB/s]
# model-00001-of-00002.safetensors:  62% 3.09G/4.99G [03:03<00:15, 122MB/s]
# model-00001-of-00002.safetensors:  62% 3.11G/4.99G [03:03<00:13, 139MB/s]
# model-00001-of-00002.safetensors:  63% 3.15G/4.99G [03:03<00:11, 165MB/s]
#
# model-00002-of-00002.safetensors:  70% 3.17G/4.53G [03:03<00:16, 82.8MB/s]
# model-00001-of-00002.safetensors:  64% 3.18G/4.99G [03:04<00:09, 186MB/s]
# model-00001-of-00002.safetensors:  64% 3.20G/4.99G [03:04<00:09, 186MB/s]
#
# model-00002-of-00002.safetensors:  70% 3.18G/4.53G [03:04<00:19, 71.1MB/s]
# model-00001-of-00002.safetensors:  64% 3.22G/4.99G [03:04<00:10, 167MB/s]
#
# model-00002-of-00002.safetensors:  71% 3.20G/4.53G [03:04<00:15, 83.7MB/s]
# model-00001-of-00002.safetensors:  65% 3.24G/4.99G [03:04<00:10, 161MB/s]
#
# model-00002-of-00002.safetensors:  71% 3.22G/4.53G [03:04<00:13, 101MB/s]
# model-00001-of-00002.safetensors:  65% 3.26G/4.99G [03:04<00:11, 146MB/s]
#
# model-00002-of-00002.safetensors:  72% 3.24G/4.53G [03:04<00:12, 107MB/s]
# model-00001-of-00002.safetensors:  66% 3.28G/4.99G [03:04<00:12, 142MB/s]
#
# model-00002-of-00002.safetensors:  72% 3.26G/4.53G [03:04<00:11, 114MB/s]
#
# model-00002-of-00002.safetensors:  72% 3.28G/4.53G [03:04<00:09, 125MB/s]
# model-00001-of-00002.safetensors:  66% 3.30G/4.99G [03:04<00:12, 137MB/s]
#
# model-00002-of-00002.safetensors:  73% 3.30G/4.53G [03:05<00:08, 140MB/s]
# model-00001-of-00002.safetensors:  67% 3.32G/4.99G [03:05<00:11, 144MB/s]
#
# model-00002-of-00002.safetensors:  73% 3.32G/4.53G [03:05<00:08, 135MB/s]
# model-00001-of-00002.safetensors:  67% 3.34G/4.99G [03:05<00:11, 138MB/s]
#
# model-00002-of-00002.safetensors:  74% 3.34G/4.53G [03:05<00:08, 140MB/s]
# model-00001-of-00002.safetensors:  67% 3.37G/4.99G [03:05<00:11, 144MB/s]
#
# model-00002-of-00002.safetensors:  74% 3.37G/4.53G [03:05<00:08, 133MB/s]
# model-00001-of-00002.safetensors:  68% 3.39G/4.99G [03:05<00:12, 124MB/s]
#
# model-00002-of-00002.safetensors:  75% 3.39G/4.53G [03:05<00:08, 130MB/s]
# model-00001-of-00002.safetensors:  68% 3.41G/4.99G [03:05<00:11, 134MB/s]
#
# model-00002-of-00002.safetensors:  75% 3.41G/4.53G [03:05<00:08, 126MB/s]
# model-00001-of-00002.safetensors:  69% 3.43G/4.99G [03:05<00:12, 128MB/s]
#
# model-00002-of-00002.safetensors:  76% 3.43G/4.53G [03:06<00:09, 119MB/s]
# model-00001-of-00002.safetensors:  69% 3.45G/4.99G [03:06<00:12, 120MB/s]
#
# model-00002-of-00002.safetensors:  76% 3.45G/4.53G [03:06<00:08, 133MB/s]
# model-00001-of-00002.safetensors:  69% 3.47G/4.99G [03:06<00:11, 131MB/s]
#
# model-00002-of-00002.safetensors:  77% 3.48G/4.53G [03:06<00:06, 166MB/s]
# model-00001-of-00002.safetensors:  70% 3.49G/4.99G [03:06<00:10, 142MB/s]
#
# model-00002-of-00002.safetensors:  77% 3.50G/4.53G [03:06<00:07, 137MB/s]
# model-00001-of-00002.safetensors:  70% 3.51G/4.99G [03:06<00:12, 117MB/s]
#
# model-00002-of-00002.safetensors:  78% 3.52G/4.53G [03:06<00:08, 119MB/s]
# model-00001-of-00002.safetensors:  71% 3.53G/4.99G [03:06<00:14, 103MB/s]
#
# model-00002-of-00002.safetensors:  78% 3.54G/4.53G [03:09<00:48, 20.5MB/s]
# model-00001-of-00002.safetensors:  71% 3.55G/4.99G [03:09<01:12, 19.9MB/s]
#
# model-00002-of-00002.safetensors:  79% 3.58G/4.53G [03:09<00:30, 31.7MB/s]
# model-00001-of-00002.safetensors:  72% 3.59G/4.99G [03:10<00:45, 30.7MB/s]
#
# model-00002-of-00002.safetensors:  79% 3.60G/4.53G [03:10<00:23, 40.1MB/s]
# model-00001-of-00002.safetensors:  72% 3.61G/4.99G [03:10<00:35, 39.5MB/s]
#
# model-00002-of-00002.safetensors:  80% 3.62G/4.53G [03:10<00:17, 51.5MB/s]
# model-00001-of-00002.safetensors:  73% 3.63G/4.99G [03:10<00:26, 50.7MB/s]
#
# model-00002-of-00002.safetensors:  80% 3.64G/4.53G [03:10<00:13, 64.1MB/s]
# model-00001-of-00002.safetensors:  73% 3.65G/4.99G [03:10<00:21, 62.9MB/s]
#
# model-00002-of-00002.safetensors:  81% 3.67G/4.53G [03:10<00:09, 87.3MB/s]
# model-00001-of-00002.safetensors:  73% 3.67G/4.99G [03:10<00:16, 78.6MB/s]
# model-00001-of-00002.safetensors:  74% 3.69G/4.99G [03:10<00:15, 84.2MB/s]
#
# model-00002-of-00002.safetensors:  81% 3.69G/4.53G [03:10<00:09, 87.7MB/s]
#
# model-00002-of-00002.safetensors:  82% 3.71G/4.53G [03:10<00:08, 97.6MB/s]
# model-00001-of-00002.safetensors:  74% 3.71G/4.99G [03:10<00:14, 91.0MB/s]
#
# model-00002-of-00002.safetensors:  82% 3.73G/4.53G [03:11<00:08, 98.7MB/s]
# model-00001-of-00002.safetensors:  75% 3.73G/4.99G [03:11<00:13, 94.7MB/s]
#
# model-00002-of-00002.safetensors:  83% 3.75G/4.53G [03:21<01:51, 6.94MB/s]
# model-00001-of-00002.safetensors:  75% 3.75G/4.99G [03:21<03:14, 6.39MB/s]
# model-00001-of-00002.safetensors:  75% 3.75G/4.99G [03:38<03:14, 6.39MB/s]
#
# model-00002-of-00002.safetensors:  83% 3.75G/4.53G [03:38<01:51, 6.94MB/s]
#
# model-00002-of-00002.safetensors:  83% 3.76G/4.53G [03:41<05:38, 2.26MB/s]
# model-00001-of-00002.safetensors:  75% 3.76G/4.99G [03:48<11:40, 1.76MB/s]
# model-00001-of-00002.safetensors:  75% 3.76G/4.99G [03:58<11:40, 1.76MB/s]
#
# model-00002-of-00002.safetensors:  83% 3.76G/4.53G [03:58<05:38, 2.26MB/s]
#
# model-00002-of-00002.safetensors:  83% 3.77G/4.53G [04:02<09:36, 1.31MB/s]
# model-00001-of-00002.safetensors:  76% 3.77G/4.99G [04:02<15:03, 1.35MB/s]
#
# model-00002-of-00002.safetensors:  84% 3.79G/4.53G [04:02<07:25, 1.67MB/s]
# model-00001-of-00002.safetensors:  76% 3.80G/4.99G [04:03<09:28, 2.11MB/s]
# model-00001-of-00002.safetensors:  77% 3.83G/4.99G [04:03<05:13, 3.73MB/s]
#
# model-00002-of-00002.safetensors:  84% 3.81G/4.53G [04:03<04:30, 2.68MB/s]
# model-00001-of-00002.safetensors:  77% 3.85G/4.99G [04:03<03:38, 5.24MB/s]
#
# model-00002-of-00002.safetensors:  85% 3.84G/4.53G [04:03<02:23, 4.82MB/s]
# model-00001-of-00002.safetensors:  77% 3.87G/4.99G [04:03<02:33, 7.32MB/s]
#
# model-00002-of-00002.safetensors:  85% 3.87G/4.53G [04:03<01:24, 7.82MB/s]
# model-00001-of-00002.safetensors:  78% 3.89G/4.99G [04:03<01:47, 10.3MB/s]
#
# model-00002-of-00002.safetensors:  86% 3.89G/4.53G [04:03<01:00, 10.6MB/s]
#
# model-00002-of-00002.safetensors:  86% 3.91G/4.53G [04:03<00:43, 14.2MB/s]
# model-00001-of-00002.safetensors:  78% 3.91G/4.99G [04:03<01:17, 14.0MB/s]
# model-00001-of-00002.safetensors:  79% 3.93G/4.99G [04:04<00:55, 19.0MB/s]
#
# model-00002-of-00002.safetensors:  87% 3.93G/4.53G [04:04<00:31, 19.0MB/s]
# model-00001-of-00002.safetensors:  79% 3.95G/4.99G [04:04<00:40, 25.4MB/s]
#
# model-00002-of-00002.safetensors:  87% 3.95G/4.53G [04:04<00:23, 25.0MB/s]
# model-00001-of-00002.safetensors:  80% 3.97G/4.99G [04:04<00:30, 33.6MB/s]
#
# model-00002-of-00002.safetensors:  88% 3.97G/4.53G [04:04<00:16, 33.2MB/s]
#
# model-00002-of-00002.safetensors:  88% 4.00G/4.53G [04:04<00:12, 41.7MB/s]
# model-00001-of-00002.safetensors:  80% 4.00G/4.99G [04:04<00:23, 41.7MB/s]
#
# model-00002-of-00002.safetensors:  89% 4.02G/4.53G [04:04<00:09, 51.9MB/s]
# model-00001-of-00002.safetensors:  80% 4.02G/4.99G [04:04<00:18, 52.3MB/s]
#
# model-00002-of-00002.safetensors:  89% 4.04G/4.53G [04:04<00:07, 64.7MB/s]
# model-00001-of-00002.safetensors:  81% 4.04G/4.99G [04:04<00:14, 64.0MB/s]
#
# model-00002-of-00002.safetensors:  90% 4.06G/4.53G [04:05<00:06, 72.9MB/s]
# model-00001-of-00002.safetensors:  81% 4.06G/4.99G [04:05<00:12, 74.6MB/s]
# model-00001-of-00002.safetensors:  82% 4.08G/4.99G [04:05<00:10, 86.7MB/s]
#
# model-00002-of-00002.safetensors:  90% 4.08G/4.53G [04:05<00:05, 84.4MB/s]
#
# model-00002-of-00002.safetensors:  91% 4.10G/4.53G [04:05<00:04, 92.9MB/s]
# model-00001-of-00002.safetensors:  82% 4.10G/4.99G [04:05<00:09, 94.1MB/s]
#
# model-00002-of-00002.safetensors:  91% 4.12G/4.53G [04:05<00:03, 104MB/s]
# model-00001-of-00002.safetensors:  83% 4.12G/4.99G [04:05<00:08, 105MB/s]
#
# model-00002-of-00002.safetensors:  91% 4.14G/4.53G [04:05<00:03, 113MB/s]
# model-00001-of-00002.safetensors:  83% 4.14G/4.99G [04:05<00:08, 99.6MB/s]
#
# model-00002-of-00002.safetensors:  92% 4.16G/4.53G [04:05<00:03, 113MB/s]
# model-00001-of-00002.safetensors:  83% 4.16G/4.99G [04:05<00:07, 107MB/s]
#
# model-00002-of-00002.safetensors:  92% 4.18G/4.53G [04:05<00:02, 121MB/s]
# model-00001-of-00002.safetensors:  84% 4.18G/4.99G [04:06<00:07, 112MB/s]
#
# model-00002-of-00002.safetensors:  93% 4.20G/4.53G [04:06<00:02, 138MB/s]
# model-00001-of-00002.safetensors:  84% 4.20G/4.99G [04:06<00:07, 105MB/s]
#
# model-00002-of-00002.safetensors:  93% 4.23G/4.53G [04:06<00:02, 121MB/s]
#
# model-00002-of-00002.safetensors:  94% 4.25G/4.53G [04:06<00:02, 125MB/s]
# model-00001-of-00002.safetensors:  85% 4.23G/4.99G [04:06<00:07, 106MB/s]
#
# model-00002-of-00002.safetensors:  94% 4.27G/4.53G [04:06<00:01, 134MB/s]
# model-00001-of-00002.safetensors:  85% 4.25G/4.99G [04:06<00:06, 117MB/s]
#
# model-00002-of-00002.safetensors:  95% 4.29G/4.53G [04:06<00:01, 133MB/s]
# model-00001-of-00002.safetensors:  85% 4.27G/4.99G [04:06<00:06, 119MB/s]
#
# model-00002-of-00002.safetensors:  95% 4.31G/4.53G [04:06<00:01, 136MB/s]
# model-00001-of-00002.safetensors:  86% 4.29G/4.99G [04:06<00:05, 129MB/s]
# model-00001-of-00002.safetensors:  86% 4.31G/4.99G [04:07<00:05, 129MB/s]
#
# model-00002-of-00002.safetensors:  96% 4.33G/4.53G [04:07<00:01, 121MB/s]
# model-00001-of-00002.safetensors:  87% 4.33G/4.99G [04:07<00:05, 130MB/s]
#
# model-00002-of-00002.safetensors:  96% 4.35G/4.53G [04:07<00:01, 119MB/s]
# model-00001-of-00002.safetensors:  87% 4.35G/4.99G [04:07<00:05, 127MB/s]
#
# model-00002-of-00002.safetensors:  97% 4.37G/4.53G [04:07<00:01, 123MB/s]
# model-00001-of-00002.safetensors:  88% 4.37G/4.99G [04:07<00:04, 134MB/s]
#
# model-00002-of-00002.safetensors:  97% 4.39G/4.53G [04:07<00:01, 132MB/s]
# model-00001-of-00002.safetensors:  88% 4.39G/4.99G [04:07<00:04, 124MB/s]
#
# model-00002-of-00002.safetensors:  97% 4.41G/4.53G [04:07<00:00, 120MB/s]
# model-00001-of-00002.safetensors:  88% 4.41G/4.99G [04:07<00:04, 121MB/s]
#
# model-00002-of-00002.safetensors:  98% 4.44G/4.53G [04:07<00:00, 123MB/s]
# model-00001-of-00002.safetensors:  89% 4.44G/4.99G [04:08<00:04, 133MB/s]
#
# model-00002-of-00002.safetensors:  98% 4.46G/4.53G [04:08<00:00, 123MB/s]
# model-00001-of-00002.safetensors:  89% 4.46G/4.99G [04:08<00:04, 127MB/s]
#
# model-00002-of-00002.safetensors:  99% 4.48G/4.53G [04:08<00:00, 120MB/s]
# model-00001-of-00002.safetensors:  90% 4.48G/4.99G [04:08<00:04, 129MB/s]
#
# model-00002-of-00002.safetensors:  99% 4.50G/4.53G [04:08<00:00, 129MB/s]
# model-00001-of-00002.safetensors:  90% 4.50G/4.99G [04:08<00:03, 131MB/s]
#
# model-00002-of-00002.safetensors: 100% 4.52G/4.53G [04:08<00:00, 134MB/s]
# model-00002-of-00002.safetensors: 100% 4.53G/4.53G [04:08<00:00, 18.2MB/s]
#
# model-00001-of-00002.safetensors:  91% 4.55G/4.99G [04:08<00:02, 148MB/s]
# model-00001-of-00002.safetensors:  92% 4.58G/4.99G [04:09<00:02, 179MB/s]
# model-00001-of-00002.safetensors:  92% 4.61G/4.99G [04:09<00:01, 201MB/s]
# model-00001-of-00002.safetensors:  93% 4.65G/4.99G [04:09<00:01, 218MB/s]
# model-00001-of-00002.safetensors:  94% 4.68G/4.99G [04:09<00:01, 197MB/s]
# model-00001-of-00002.safetensors:  94% 4.70G/4.99G [04:09<00:01, 181MB/s]
# model-00001-of-00002.safetensors:  94% 4.72G/4.99G [04:09<00:01, 148MB/s]
# model-00001-of-00002.safetensors:  95% 4.74G/4.99G [04:10<00:02, 118MB/s]
# model-00001-of-00002.safetensors:  95% 4.76G/4.99G [04:10<00:01, 124MB/s]
# model-00001-of-00002.safetensors:  96% 4.78G/4.99G [04:10<00:01, 133MB/s]
# model-00001-of-00002.safetensors:  96% 4.80G/4.99G [04:10<00:01, 138MB/s]
# model-00001-of-00002.safetensors:  97% 4.83G/4.99G [04:10<00:00, 170MB/s]
# model-00001-of-00002.safetensors:  97% 4.87G/4.99G [04:10<00:00, 200MB/s]
# model-00001-of-00002.safetensors:  98% 4.90G/4.99G [04:10<00:00, 225MB/s]
# model-00001-of-00002.safetensors:  99% 4.93G/4.99G [04:13<00:02, 31.3MB/s]
# model-00001-of-00002.safetensors:  99% 4.96G/4.99G [04:13<00:00, 43.5MB/s]
# model-00001-of-00002.safetensors: 100% 4.99G/4.99G [04:13<00:00, 19.7MB/s]
# Fetching 2 files: 100% 2/2 [04:14<00:00, 127.04s/it]
# Loading checkpoint shards: 100% 2/2 [00:53<00:00, 26.67s/it]
# model_index.json: 100% 706/706 [00:00<00:00, 6.09MB/s]
# Fetching 18 files:   0% 0/18 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
#
# model.safetensors:   0% 0.00/247M [00:00<?, ?B/s]
#
#
# tokenizer_config.json: 100% 705/705 [00:00<00:00, 3.99MB/s]
#
#
#
# config.json: 100% 574/574 [00:00<00:00, 4.82MB/s]
#
#
#
# scheduler_config.json: 100% 141/141 [00:00<00:00, 893kB/s]
# Fetching 18 files:  11% 2/18 [00:00<00:01,  9.02it/s]
#
#
# merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
#
# config.json: 100% 570/570 [00:00<00:00, 4.49MB/s]
#
# model.safetensors:   2% 21.0M/1.39G [00:00<00:09, 140MB/s]
#
# model.safetensors:   8% 21.0M/247M [00:00<00:01, 141MB/s]
#
#
# merges.txt: 100% 525k/525k [00:00<00:00, 3.97MB/s]
#
#
#
# vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
# model.safetensors:   4% 52.4M/1.39G [00:00<00:06, 195MB/s]
#
# model.safetensors:  21% 52.4M/247M [00:00<00:00, 197MB/s]
#
#
#
# special_tokens_map.json: 100% 588/588 [00:00<00:00, 3.77MB/s]
#
#
#
#
# tokenizer_config.json: 100% 856/856 [00:00<00:00, 6.99MB/s]
#
#
#
#
# special_tokens_map.json: 100% 2.54k/2.54k [00:00<00:00, 10.9MB/s]
#
#
#
#
# special_tokens_map.json: 100% 576/576 [00:00<00:00, 3.76MB/s]
#
#
# model.safetensors:  30% 73.4M/247M [00:00<00:00, 181MB/s]
#
#
# vocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.22MB/s]
#
# model.safetensors:   6% 83.9M/1.39G [00:00<00:07, 186MB/s]
#
#
# spiece.model: 100% 792k/792k [00:00<00:00, 18.8MB/s]
#
#
#
# tokenizer.json:   0% 0.00/2.42M [00:00<?, ?B/s]
#
# model.safetensors:  38% 94.4M/247M [00:00<00:00, 154MB/s]
# model.safetensors:   8% 105M/1.39G [00:00<00:07, 167MB/s]
#
#
#
# tokenizer_config.json: 100% 20.6k/20.6k [00:00<00:00, 67.9MB/s]
#
#
# model.safetensors:  47% 115M/247M [00:00<00:00, 142MB/s]
# model.safetensors:   9% 126M/1.39G [00:00<00:08, 148MB/s]
#
#
# tokenizer.json: 100% 2.42M/2.42M [00:00<00:00, 9.61MB/s]
#
# model.safetensors:  11% 147M/1.39G [00:00<00:08, 150MB/s]
#
# model.safetensors:  55% 136M/247M [00:00<00:00, 135MB/s]
# model.safetensors:  12% 168M/1.39G [00:01<00:08, 149MB/s]
#
# model.safetensors:  64% 157M/247M [00:01<00:00, 140MB/s]
#
# model.safetensors:  72% 178M/247M [00:01<00:00, 142MB/s]
# model.safetensors:  14% 189M/1.39G [00:01<00:08, 144MB/s]
#
# model.safetensors:  81% 199M/247M [00:01<00:00, 148MB/s]
# model.safetensors:  15% 210M/1.39G [00:01<00:08, 139MB/s]
#
# model.safetensors:  89% 220M/247M [00:01<00:00, 152MB/s]
# model.safetensors:  17% 231M/1.39G [00:01<00:07, 147MB/s]
#
# model.safetensors:  98% 241M/247M [00:01<00:00, 156MB/s]
# model.safetensors: 100% 247M/247M [00:01<00:00, 150MB/s]
# Fetching 18 files:  22% 4/18 [00:01<00:07,  1.92it/s]
# model.safetensors:  20% 273M/1.39G [00:01<00:07, 153MB/s]
# model.safetensors:  21% 294M/1.39G [00:01<00:07, 146MB/s]
# model.safetensors:  23% 315M/1.39G [00:02<00:06, 158MB/s]
# model.safetensors:  24% 336M/1.39G [00:02<00:07, 144MB/s]
# model.safetensors:  26% 357M/1.39G [00:02<00:08, 120MB/s]
# model.safetensors:  27% 377M/1.39G [00:08<01:33, 10.8MB/s]
# model.safetensors:  28% 388M/1.39G [00:08<01:19, 12.6MB/s]
# model.safetensors:  29% 398M/1.39G [00:08<01:07, 14.7MB/s]
# model.safetensors:  29% 409M/1.39G [00:09<00:59, 16.4MB/s]
# model.safetensors:  30% 419M/1.39G [00:14<02:30, 6.46MB/s]
# model.safetensors:  30% 419M/1.39G [00:25<02:30, 6.46MB/s]
# model.safetensors:  31% 430M/1.39G [00:29<07:48, 2.05MB/s]
# model.safetensors:  31% 430M/1.39G [00:40<07:48, 2.05MB/s]
# model.safetensors:  32% 440M/1.39G [00:48<13:17, 1.19MB/s]
# model.safetensors:  34% 472M/1.39G [00:48<06:00, 2.55MB/s]
# model.safetensors:  36% 503M/1.39G [00:48<03:19, 4.45MB/s]
# model.safetensors:  38% 524M/1.39G [00:48<02:20, 6.16MB/s]
# model.safetensors:  39% 545M/1.39G [00:48<01:39, 8.51MB/s]
# model.safetensors:  41% 566M/1.39G [00:49<01:09, 11.8MB/s]
# model.safetensors:  42% 587M/1.39G [00:49<00:49, 16.3MB/s]
# model.safetensors:  45% 629M/1.39G [00:49<00:26, 28.9MB/s]
# model.safetensors:  48% 671M/1.39G [00:49<00:15, 45.4MB/s]
# model.safetensors:  51% 703M/1.39G [00:49<00:11, 60.8MB/s]
# model.safetensors:  53% 734M/1.39G [00:49<00:08, 78.4MB/s]
# model.safetensors:  55% 765M/1.39G [00:49<00:06, 96.0MB/s]
# model.safetensors:  57% 797M/1.39G [00:50<00:09, 64.6MB/s]
# model.safetensors:  59% 818M/1.39G [00:55<00:35, 16.2MB/s]
# model.safetensors:  62% 860M/1.39G [00:55<00:20, 25.8MB/s]
# model.safetensors:  65% 902M/1.39G [00:55<00:12, 38.4MB/s]
# model.safetensors:  67% 933M/1.39G [00:55<00:09, 50.3MB/s]
# model.safetensors:  69% 965M/1.39G [00:55<00:06, 65.4MB/s]
# model.safetensors:  72% 996M/1.39G [00:55<00:04, 84.5MB/s]
# model.safetensors:  74% 1.03G/1.39G [00:55<00:03, 107MB/s]
# model.safetensors:  76% 1.06G/1.39G [00:56<00:02, 131MB/s]
# model.safetensors:  78% 1.09G/1.39G [00:56<00:01, 154MB/s]
# model.safetensors:  81% 1.12G/1.39G [00:56<00:01, 174MB/s]
# model.safetensors:  83% 1.15G/1.39G [00:56<00:01, 193MB/s]
# model.safetensors:  85% 1.18G/1.39G [00:56<00:00, 207MB/s]
# model.safetensors:  88% 1.22G/1.39G [00:56<00:00, 218MB/s]
# model.safetensors:  90% 1.25G/1.39G [00:56<00:00, 221MB/s]
# model.safetensors:  92% 1.28G/1.39G [00:56<00:00, 238MB/s]
# model.safetensors:  94% 1.31G/1.39G [00:57<00:00, 247MB/s]
# model.safetensors:  97% 1.34G/1.39G [00:57<00:00, 229MB/s]
# model.safetensors: 100% 1.39G/1.39G [00:57<00:00, 24.2MB/s]
# Fetching 18 files: 100% 18/18 [00:57<00:00,  3.20s/it]
# Loading pipeline components...:  14% 1/7 [00:00<00:01,  4.60it/s]You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.61it/s]
# prompt_embeds.shape=torch.Size([1, 154, 4096]), negative_prompt_embeds.shape=torch.Size([1, 154, 4096]), pooled_prompt_embeds.shape=torch.Size([1, 2048]), torch.Size([1, 2048])
# Max memory allocated: 10.457 GB
# Data successfully serialized to sample_embeddings.parquet

# %% [markdown]
# ## Clear memory

# %%
import torch
import gc


def flush():
    torch.cuda.empty_cache()
    gc.collect()

flush()

# %% [markdown]
# ## Train!

# %%
# !accelerate launch train_dreambooth_lora_sd3_miniature.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-3-medium-diffusers"  \
  --instance_data_dir="dog" \
  --data_df_path="sample_embeddings.parquet" \
  --output_dir="trained-sd3-lora-miniature" \
  --mixed_precision="fp16" \
  --instance_prompt="a photo of sks dog" \
  --resolution=1024 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 --gradient_checkpointing \
  --use_8bit_adam \
  --learning_rate=1e-4 \
  --report_to="wandb" \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=500 \
  --seed="0"
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2025-05-26 11:09:25.150962: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748257765.171560    7952 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748257765.178056    7952 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-26 11:09:25.199419: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# {'base_shift', 'time_shift_type', 'invert_sigmas', 'use_beta_sigmas', 'max_shift', 'use_dynamic_shifting', 'use_exponential_sigmas', 'stochastic_sampling', 'base_image_seq_len', 'max_image_seq_len', 'shift_terminal', 'use_karras_sigmas'} was not found in config. Values will be initialized to default values.
# config.json: 100% 739/739 [00:00<00:00, 4.19MB/s]
# diffusion_pytorch_model.safetensors: 100% 168M/168M [00:00<00:00, 208MB/s]
# {'mid_block_add_attention'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing AutoencoderKL.
#
# All the weights of AutoencoderKL were initialized from the model checkpoint at stabilityai/stable-diffusion-3-medium-diffusers.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use AutoencoderKL for predictions without further training.
# config.json: 100% 372/372 [00:00<00:00, 2.80MB/s]
# diffusion_pytorch_model.safetensors: 100% 4.17G/4.17G [00:36<00:00, 114MB/s]
# {'qk_norm', 'dual_attention_layers'} was not found in config. Values will be initialized to default values.
# All model checkpoint weights were used when initializing SD3Transformer2DModel.
#
# All the weights of SD3Transformer2DModel were initialized from the model checkpoint at stabilityai/stable-diffusion-3-medium-diffusers.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use SD3Transformer2DModel for predictions without further training.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.19.11
# wandb: W&B syncing is set to `offline` in this directory. Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# Steps:  77% 383/500 [57:13<19:17,  9.89s/it, loss=0.0354, lr=0.0001]

# %% [markdown]
# Training will take about an hour to complete depending on the length of your dataset.

# %% [markdown]
# ## Inference

# %%
flush()

# %%
from diffusers import DiffusionPipeline
import torch

pipeline = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-3-medium-diffusers",
    torch_dtype=torch.float16
)
lora_output_path = "trained-sd3-lora-miniature"
pipeline.load_lora_weights("trained-sd3-lora-miniature")

pipeline.enable_sequential_cpu_offload()

image = pipeline("a photo of sks dog in a bucket").images[0]
image.save("bucket_dog.png")

# %% [markdown]
# Note that inference will be very slow in this case because we're loading and unloading individual components of the models and that introduces significant data movement overhead. Refer to [this resource](https://huggingface.co/blog/sd3#memory-optimizations-for-sd3) for more memory optimization related techniques.
